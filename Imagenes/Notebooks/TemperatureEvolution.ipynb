# %%
import numpy as np
import matplotlib.pyplot as plt

import scipy.misc
from scipy import ndimage
import matplotlib.pyplot as plt

# %%
Te_2_5 = np.load("../T-Tiempo/Te_Temporal_XSimmetry_2.50.npy")
Ti_2_5 = np.load("../T-Tiempo/Ti_Temporal_XSimmetry2.50.npy")

t = np.linspace(0,20e-12,int(20e-12/10e-15))

# %%
last_value = 1000
plt.title(r'Temperature Evolution F = 2.5${J}/{cm^{2}}$')

plt.plot(t[:-last_value]*1e12,Te[:-last_value],ls = '--',label = '$T_{e^-}$',color="black")
plt.plot(t[:-last_value]*1e12,Ti[:-last_value],ls = 'dotted',label = '$T_{lattice}$',color="dimgrey")
plt.xlabel("Time (ps)")
plt.ylabel("Temperature(K)")
plt.legend()

# %%
Te_5 = np.load("../T-Tiempo/Te_Temporal_XSimmetry_5.00.npy")
Ti_5 = np.load("../T-Tiempo/Ti_Temporal_XSimmetry5.00.npy")

# %%
last_value = 1000
plt.title(r'Temperature Evolution F = 2${J}/{cm^{2}}$')

plt.plot(t[:-last_value]*1e12,Te_5[:-last_value],ls = '--',label = '$T_{e^-}$',color="black")
plt.plot(t[:-last_value]*1e12,Ti_5[:-last_value],ls = 'dotted',label = '$T_{lattice}$',color="dimgrey")
plt.xlabel("Time (ps)")
plt.ylabel("Temperature(K)")
plt.legend()

# %%
Te_8 = np.load("../T-Tiempo/Te_Temporal_XSimmetry_8.00.npy")
Ti_8 = np.load("../T-Tiempo/Ti_Temporal_XSimmetry8.00.npy")

# %%
last_value = 1000
plt.title(r'Temperature Evolution F = 2.5${J}/{cm^{2}}$')

plt.plot(t[:-last_value]*1e12,Te_8[:-last_value],ls = '--',label = '$T_{e^-}$',color="black")
plt.plot(t[:-last_value]*1e12,Ti_8[:-last_value],ls = 'dotted',label = '$T_{lattice}$',color="dimgrey")
plt.xlabel("Time (ps)")
plt.ylabel("Temperature(K)")
plt.legend()

# %%
Te_4 = np.load("../T-Tiempo/Te_Temporal_XSimmetry_4.00.npy")
Ti_4 = np.load("../T-Tiempo/Ti_Temporal_XSimmetry4.00.npy")

# %%
last_value = 1000
plt.title(r'Temperature Evolution F = 2.5${J}/{cm^{2}}$')

plt.plot(t[:-last_value]*1e12,Te_4[:-last_value],ls = '--',label = '$T_{e^-}$',color="black")
plt.plot(t[:-last_value]*1e12,Ti_4[:-last_value],ls = 'dotted',label = '$T_{lattice}$',color="dimgrey")
plt.xlabel("Time (ps)")
plt.ylabel("Temperature(K)")
plt.legend()

# %%
last_value = 100
i = 0
colors = plt.cm.jet(np.linspace(0, 1, 5))
plt.title(r'Temperature Evolution')
plt.plot(t[:-last_value]*1e12,Te_2_5[:-last_value],ls = 'dotted',label = '2.5 J/cm$^2$',color=colors[i])
plt.plot(t[:-last_value]*1e12,Ti_2_5[:-last_value],ls = '--',color=colors[i])
i += 1


plt.plot(t[:-last_value]*1e12,Te_4[:-last_value],ls = 'dotted',label = '4 J/cm$^2$',color=colors[i])
plt.plot(t[:-last_value]*1e12,Ti_4[:-last_value],ls = '--',color=colors[i])
i += 1

plt.plot(t[:-last_value]*1e12,Te_5[:-last_value],ls = 'dotted',label = '5 J/cm$^2$',color=colors[i])
plt.plot(t[:-last_value]*1e12,Ti_5[:-last_value],ls = '--',color=colors[i])
i += 1
plt.plot(t[:-last_value]*1e12,Te_8[:-last_value],ls = 'dotted',label = '8 J/cm$^2$',color=colors[i])
plt.plot(t[:-last_value]*1e12,Ti_8[:-last_value],ls = '--',color=colors[i])

plt.xlabel("Time (ps)")
plt.ylabel("Temperature(K)")
plt.legend()
plt.savefig("Varios Datos.png")
"

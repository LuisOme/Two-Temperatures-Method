# %%
import numpy as np
import matplotlib.pyplot as plt

import scipy.misc
from scipy import ndimage
import matplotlib.pyplot as plt

import pandas as pd
import os

# %% [markdown]
# ### Parámetros de Mallado

# %%
### RECORREMOS UNA PROFUNDIDAD

dz = 0.005e-6 ## Paso en Profundidad  nm
start_z = 0
stop_z = 3e-6

dx = 0.05e-6  ## Paso en Superficie um
start_x = 0e-6
stop_x = 8e-6

### EN UN TIEMPO 
dt = 12.5e-15  ## Time Step fs
start_t = 0
stop_t = 5e-12 ## Finalizamos a ps


x = np.linspace(start_x,stop_x,int(round((stop_x-start_x)/dx)))
z = np.linspace(start_z,stop_z,int(round((stop_z-start_z)/dz)))
t = np.linspace(start_t,stop_t,int(round((stop_t-start_t)/dt)))

X,Z= np.meshgrid(x,z)

## Auxiliar para X-Z
x_mid = x.shape[0]//2

# %% [markdown]
# ### Parámetros Generales Red y Láser

# %%
# ------------- Red Electrones -----------------
Ce_aux = 134.5 # J / (m^3 K^2)
ke = 235  # J /(m K s)
g = 5.69e17 # J /(m K^3 s)

#  ----------------------------------------------

# ------------- Red Lattice -----------------
Ci = 2.42e6  # J / (m^3 K)
ki = ke/99 # J (m K^3 s) 
#  -------------------------------------------


# ------------- Parámetros Láser -----------------
R = 0.88 # Reflectancia A.U.
delta = 20e-9 # Optical Penetration (nm)
ball_len = 100e-9 # Ballistic Length (nm)
 
tp = 100e-15 # FWHM fs
w0 = 5e-6 # Waist um
wavelength = 1.032e-6 # Wavelength (um)
#  ------------------------------------------------------

# ------------- Parámetros Varios -----------------
ys = 3e-6 ## Perfil de Apertura del Láser (um)
T0 = 300 # K Temperatura Ambiente (K)
x0 = 0 # Posición central del Spot en x
n = 1 ## Refractive Index
Zr = n*np.pi*w0**2/wavelength
w = w0*(1+Z**2/Zr**2)**1/2


Tc = 5370 # Temperatura Crítica (K)

# %% [markdown]
# ### Valores para primer pulso (Inicialización)

# %%
F = np.linspace(15.5e4,20e4,4) # Fluence J/cm^2 -> J/m^2
N = 50 # NUMERO DE PULSOS

# %%
#### CALCULOS PARA DIFERENTES FLUENCIAS
for f in F:
    if (os.path.exists(f"Resultados/Multipulse/Spot_5um/Fluence{f*1e-4:.2f}")== False):
        os.mkdir(f"Resultados/Multipulse/Spot_5um/Fluence{f*1e-4:.2f}")
    
    ### Creamos de Nuevo el Mallado Inicial para otra fluencia.
    ## Valor para cambiar el dz si se va a Z muy grande
    resample = 0
    if f != F[0]:
        dz = 0.01e-6 ## Paso en Profundidad  nm
        start_z = 0
        stop_z = 3e-6

        dx = 0.05e-6  ## Paso en Superficie um
        start_x = 0e-6
        stop_x = 8e-6

        ### EN UN TIEMPO 
        dt = 7.5e-15  ## Time Step fs
        start_t = 0
        stop_t = 5e-12 ## Finalizamos a ps


        x = np.linspace(start_x,stop_x,int(round((stop_x-start_x)/dx)))
        z = np.linspace(start_z,stop_z,int(round((stop_z-start_z)/dz)))
        t = np.linspace(start_t,stop_t,int(round((stop_t-start_t)/dt)))

        X,Z= np.meshgrid(x,z)

        ## Auxiliar para X-Z
        x_mid = x.shape[0]//2


        Zr = n*np.pi*w0**2/wavelength
        w = w0*(1+Z**2/Zr**2)**1/2
    
    
    
    depths_craters = []
    diameters_craters = []

        ### ZS PARA PRIMER PULSO ES 0
    Zs = np.zeros_like(x)

    ### LASER POWER PARA PRIMER PULSO
    T = 1/tp * np.sqrt(4 * np.log(2)/np.pi) * np.exp(
    -4*np.log(2) * ((t - 2*tp)/tp)**2)
    S = (1-R)/(delta + ball_len) * f * w0**2/w**2 * np.exp(
        -(Z-Zs)/(delta+ball_len) - (2*(X-x0)**2/w**2))

    ### PARAMETRO AUXILIAR
    s = dt/Ce_aux

    ### TEMPERATURAS INICIALES
    Te = np.ones_like(X[:,:])*300
    Ti = np.ones_like(X[:,:])*300
    Tenew,Tinew = np.zeros_like(Te), np.zeros_like(Ti)
    
#### CALCULOS PARA MULTIPULSOS
    for nn in range(N):

### CALCULOS T(Z,X) para cada tiempo
        for n in range(0,len(t)-1):
            for i in range(1,len(z)-1):
                for k in range(1,len(x)-1):
                    Tenew[i,k] = Te[i,k] + s/Te[i,k]*(
                        ke*((Te[i+1,k] - 2 * Te[i,k] + Te[i-1,k])/dz/dz + (Te[i,k+1] -2*Te[i,k] + Te[i,k-1])/dx/dx)) - (
                        s/Te[i,k]*g*(Te[i,k]-Ti[i,k])) + s/Te[i,k]*S[i,k]*T[n]

                    Tinew[i,k] = Ti[i,k] + dt/Ci*ki*((Ti[i+1,k]-2*Ti[i,k]-Ti[i-1,k])/dz/dz + (Ti[i,k-1]-2*Ti[i,k+1]+Ti[i,k+1])/dx/dx) +dt/Ci * g * (Te[i,k] - Ti[i,k])

            ### CONDICIONES DE CONTORNO
            Tenew[0,:], Tenew[-1,:], Tenew[:,0], Tenew[:,-1] = Tenew[1,:], Tenew[-2,:], Tenew[:,1], Tenew[:,-2]
            Tinew[0,:], Tinew[-1,:], Tinew[:,0], Tinew[:,-1] = Tinew[1,:], Tinew[-2,:], Tinew[:,1], Tinew[:,-2]
            Te = Tenew
            Ti = Tinew

            if (n == 0 or n == int(len(t)-2)//2 or n == len(t)-2):

                fig, ((ax4)) = plt.subplots(1,1,figsize=(7.5,7.5))
                plt.gca().invert_yaxis()
                fig.tight_layout()

                fig.subplots_adjust(hspace=0.5,wspace=0.5)
                fig.suptitle(f'Pulse {nn+1} for t: {t[n]*1e15:.2f} fs at F: {f*1e-4:.2f} J/cm^2',y = 1.05,fontname="Times New Roman", fontweight="bold")


                im4 = ax4.pcolor(x*1e6,z*1e6,Ti[:,:],vmin = 300,vmax = 6500,cmap="RdYlBu_r",)
                # fig.colorbar(im4)
                ax4.set_title("$T_{lattice}$ Perfil X-Z ")
                ax4.set_xlabel("X ($\mu m$)")
                ax4.set_ylabel("Z ($\mu m$)")

                plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
                cax = plt.axes([0.84, 0.05, 0.020, 0.85])
                plt.colorbar(im4,cax=cax)
                plt.show()

        ### OBTENEMOS EL NUEVO PERFIL DE ABLACION    
        X_profile = Ti[0,:]
        for u in range(len(x)):
            for v in range(len(z)):
                ### CALCULO DE Zs y de Profundidad del Pulso
                if Ti[v,u] < 0.9*Tc:
                    z_aux = Z[v,u]
                    # print(z_aux)
                    Zs[u] = z_aux
                    if u == 0:
                        depths_craters.append(z_aux)
                    break
            ### CALCULO DE DIAMETRO DLE PULSO
            if (X_profile[u] < 0.9*Tc):
                diameters_craters.append(2*x[u])
                break
        
        if (len(depths_craters) < nn+1):
            depths_craters.append(z[-1])
            print("MALLADO SUPERADO")
            S = (1-R)/(delta + ball_len) * f * w0**2/w**2 * np.exp(
            -(Z-Zs)/(delta+ball_len) - (2*(X-x0)**2/w**2))


            Te = np.ones_like(Ti[:,:])*300
            Ti = np.ones_like(Ti[:,:])*300
            Tenew,Tinew = np.zeros_like(Te), np.zeros_like(Ti)

            # np.save(f"Diameters_{N}_Pulses_{f*1e-4}_Fluence",diameters_craters)
            # np.save(f"Depth_{N}_Pulses_{f*1e-4}_Fluence",depths_craters)
        
            break
            
            
        print(f"Depth Crater pulse {nn+1}: {depths_craters[nn]*1e6:.2f} um")
        print(f"Diameter Crater pulse {nn+1}: {diameters_craters[nn]*1e6:.2f} um")

  #### AJUSTAMOS EL MALLADO DE NUEVO
        #### PASAMOS DE Z SI NO USAMOS TODO A UNA MÁS PEQUEÑA
        if (Ti[:int(len(z)*0.5),0] < 350).any():
            print("Reducimos Z")
            stop_z = stop_z/2
            z = np.linspace(start_z,stop_z,int(round((stop_z-start_z)/dz)))
            X,Z= np.meshgrid(x,z)
            # Zs = Zs[:len(z),:]

        elif (Ti[:int(len(z)*0.7),0]> 0.7*Tc).all() :
            print("Aumentamos Z")
            stop_z = (stop_z/0.75)                
            z = np.linspace(start_z,stop_z,int(round((stop_z-start_z)/dz)))
            X,Z= np.meshgrid(x,z)
            # Zs = np.concatenate((Zs,Zs),axis = 0)

        if (Ti[0,:int(len(x)*0.75)]< 350).any() :
            print("Reducimos en X")
            stop_x = stop_x*0.75
            x = np.linspace(start_x,stop_x,int(round((stop_x-start_x)/dx)))
            X,Z= np.meshgrid(x,z)
            Zs = Zs[:len(x)]
        elif (Ti[0,:int(len(x)*0.75)]> 0.7*Tc).all():
            print("Aumentamos X")
            stop_x = stop_x*2
            x = np.linspace(start_x,stop_x,int(round((stop_x-start_x)/dx)))
            X,Z= np.meshgrid(x,z)
            Zs = np.concatenate((Zs,np.zeros_like(Zs)),axis=1)
        
        w = w0*(1+Z**2/Zr**2)**1/2
        ### CALCULAMOS EL NUEVO POWER LASER
        S = (1-R)/(delta + ball_len) * f * w0**2/w**2 * np.exp(
        -(Z-Zs)/(delta+ball_len) - (2*(X-x0)**2/w**2))

        Te = np.ones_like(X[:,:])*300
        Ti = np.ones_like(X[:,:])*300
        Tenew,Tinew = np.zeros_like(Te), np.zeros_like(Ti)
        
        # np.save(f"Resultados/Multipulse/Spot_5um/Fluence{f*1e-4:.2f}/Diameters_{N}_Pulses",diameters_craters)
        # np.save(f"Resultados/Multipulse/Spot_5um/Fluence{f*1e-4:.2f}/Depth_{N}Pulses",depths_craters)
    
    # np.save(f"Resultados/Multipulse/Spot_5um/Fluence{f*1e-4:.2f}/Diameters_{N}_Pulses",diameters_craters)
    # np.save(f"Resultados/Multipulse/Spot_5um/Fluence{f*1e-4:.2f}/Depth_{N}Pulses",depths_craters)
# Out:
# MALLADO SUPERADO
# Depth Crater pulse 1: 0.48 um
# Diameter Crater pulse 1: 6.84 um
# Reducimos Z
# Reducimos en X
# Depth Crater pulse 2: 0.97 um
# Diameter Crater pulse 2: 6.96 um
# Depth Crater pulse 3: 1.45 um
# Diameter Crater pulse 3: 6.96 um
# Aumentamos Z
# Depth Crater pulse 4: 1.93 um
# Diameter Crater pulse 4: 6.96 um
# Aumentamos Z
# Depth Crater pulse 5: 2.41 um
# Diameter Crater pulse 5: 7.06 um
# Aumentamos Z
# Depth Crater pulse 6: 2.88 um
# Diameter Crater pulse 6: 7.06 um
# Aumentamos Z
# Depth Crater pulse 7: 3.37 um
# Diameter Crater pulse 7: 7.06 um
# Aumentamos Z
# Depth Crater pulse 8: 3.85 um
# Diameter Crater pulse 8: 7.06 um
# Depth Crater pulse 9: 4.33 um
# Diameter Crater pulse 9: 7.06 um
# Depth Crater pulse 10: 4.81 um
# Diameter Crater pulse 10: 7.16 um
# Aumentamos Z
# Depth Crater pulse 11: 5.29 um
# Diameter Crater pulse 11: 7.16 um
# Depth Crater pulse 12: 5.77 um
# Diameter Crater pulse 12: 7.16 um
# Depth Crater pulse 13: 6.25 um
# Diameter Crater pulse 13: 7.16 um
# Aumentamos Z
# Depth Crater pulse 14: 6.72 um
# Diameter Crater pulse 14: 7.16 um
# Depth Crater pulse 15: 7.20 um
# Diameter Crater pulse 15: 7.26 um

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Diameters = np.load("Diameters_50_Pulses_5.0_Fluence.npy")
Depths = np.load("Depth_50_Pulses_5.0_Fluence.npy")

# %%
x = range(len(Diameters))
plt.scatter(x,Diameters)

# %%
x = range(len(Depths))
plt.scatter(x,Depths)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
### RECORREMOS UNA PROFUNDIDAD

dz = 0.008e-6 ## Paso en Profundidad  nm
start_z = 0
stop_z = 1e-6

dx = 0.1e-6  ## Paso en Superficie um
start_x = 0e-6
stop_x = 10e-6

### EN UN TIEMPO 
dt = 10e-15  ## Time Step fs
start_t = 0
stop_t = 20e-12 ## Finalizamos a ps

x = np.linspace(start_x,stop_x,int(round((stop_x-start_x)/dx)))
z = np.linspace(start_z,stop_z,int(round((stop_z-start_z)/dz)))
t = np.linspace(start_t,stop_t,int(round((stop_t-start_t)/dt)))

X,Z= np.meshgrid(x,z)

## Auxiliar para Plot X-Z en punto medio de Y
x_mid = x.shape[0]//2

# %%
# ------------- Red Electrones -----------------
Ce_aux = 134.5 # J / (m^3 K^2)
ke = 235  # J /(m K s)
g = 5.69e17 # J /(m K^3 s)

#  ----------------------------------------------

# ------------- Red Lattice -----------------
Ci = 2.42e6  # J / (m^3 K)
#  -------------------------------------------


# ------------- Parámetros Láser -----------------
R = 0.88 # Reflectancia A.U.
delta = 20e-9 # Optical Penetration (nm)
ball_len = 100e-9 # Ballistic Length (nm)
 
tp = 100e-15 # FWHM fs
w0 = 5e-6 # Waist um
wavelength = 1.032e-6 # Wavelength (um)
#  ------------------------------------------------------

# ------------- Parámetros Varios -----------------
ys = 3e-6 ## Perfil de Apertura del Láser (um)
T0 = 300 # K Temperatura Ambiente (K)
x0 = 0 # Posición central del Spot en x
y0 = 0 # Posición central del Spot en y
zs = 0 # Z superficial
n = 1 ## Refractive Index
Zr = n*np.pi*w0**2/wavelength
w = w0*(1+Z**2/Zr**2)**1/2

# %%
F = 2.0e4 # J/cm**2

# %%
Z.shape
# Out:
# (125, 100)

# %%
z.shape
# Out:
# (125,)

# %%
radius_crater
# Out:
# 1.385e-06

# %%
ZS = depth_crater * np.sqrt(1-X**2/radius_crater**2)
ZS = np.nan_to_num(ZS,copy = False)
# Out:
# C:\Users\lomenaca\AppData\Local\Temp\ipykernel_19696\1893438325.py:1: RuntimeWarning: invalid value encountered in sqrt
#   ZS = depth_crater * np.sqrt(1-X**2/radius_crater**2)

# %%
plt.imshow(ZS,cmap='jet')
plt.colorbar()

# %%
plt.pcolor(Z[:,:]-ZS[:,:],cmap="jet")
plt.gca().invert_yaxis()
plt.colorbar()

# %%
### Cálculos de la Fuente Laser 
    # Q(x,y,z,t) = T(t) * S(x,y,z)

T = 1/tp * np.sqrt(4 * np.log(2)/np.pi) * np.exp(
-4*np.log(2) * ((t - 2*tp)/tp)**2)

S = (1-R)/(delta + ball_len) * F * w0**2/w**2 * np.exp(
-(Z-ZS)/(delta+ball_len) - (2*(X-x0)**2/w**2))

S_fix = (1-R)/(delta + ball_len) * F * w0**2/w**2 * np.exp(
-(Z)/(delta+ball_len) - (2*(X-x0)**2/w**2))

plt.pcolor(x,z,S,cmap='jet',vmin = S_fix.min(),vmax = S_fix.max())
plt.gca().invert_yaxis()
plt.title("Z-ZS")
plt.colorbar(cmap='jet',)
plt.show()
    
plt.pcolor(x,z,S_fix,cmap='jet',vmin = S_fix.min(),vmax = S_fix.max())
plt.gca().invert_yaxis()
plt.title("Z")
plt.colorbar(cmap='jet')
plt.show()

# %%
plt.scatter(x,S[0,:],s=2,c="orange",label = "New Pulse")
plt.plot(x,S_fix[0,:],alpha=0.2,label = "Old Pulse")
plt.axvline(radius_crater,ls="dotted",label = "Radio Crater",c="green")
plt.legend()

# %%
plt.pcolor(x[75:125],z[0:10],(S[0:10,75:125]-S_fix[0:10,75:125]),cmap = 'jet')
plt.gca().invert_yaxis()
plt.colorbar(cmap='jet')
plt.axvline(radius_crater,c="red",lw=3)

# %%
x.shape
# Out:
# (200,)

# %%
plt.pcolor(x,z,S_fix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 plt.pcolor(x,z,S_fix)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2687, in pcolor(shading, alpha, norm, cmap, vmin, vmax, data, *args, **kwargs)
#    2683 @_copy_docstring_and_deprecators(Axes.pcolor)
#    2684 def pcolor(
#    2685         *args, shading=None, alpha=None, norm=None, cmap=None,
#    2686         vmin=None, vmax=None, data=None, **kwargs):
# -> 2687     __ret = gca().pcolor(
#    2688         *args, shading=shading, alpha=alpha, norm=norm, cmap=cmap,
#    2689         vmin=vmin, vmax=vmax,
#    2690         **({"data": data} if data is not None else {}), **kwargs)
#    2691     sci(__ret)
#    2692     return __ret
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:5897, in Axes.pcolor(self, shading, alpha, norm, cmap, vmin, vmax, *args, **kwargs)
#    5895     shading = mpl.rcParams['pcolor.shading']
#    5896 shading = shading.lower()
# -> 5897 X, Y, C, shading = self._pcolorargs('pcolor', *args, shading=shading,
#    5898                                     kwargs=kwargs)
#    5899 Ny, Nx = X.shape
#    5901 # convert to MA, if necessary.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:5691, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    5689 if shading == 'flat':
#    5690     if (Nx, Ny) != (ncols + 1, nrows + 1):
# -> 5691         raise TypeError('Dimensions of C %s are incompatible with'
#    5692                         ' X (%d) and/or Y (%d); see help(%s)' % (
#    5693                             C.shape, Nx, Ny, funcname))
#    5694 else:    # ['nearest', 'gouraud']:
#    5695     if (Nx, Ny) != (ncols, nrows):
#
# TypeError: Dimensions of C (125, 200) are incompatible with X (100) and/or Y (125); see help(pcolor)
